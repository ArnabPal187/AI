# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnabPal187/AI/blob/main/NLP_IN_DEEP_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Simple RNN-> Recurrent Neural Network -> to process sequential data
